# %%
import pandas as pd

# %%
data_1 = pd.read_csv('../data/interim/pregnancy_recode.csv')
data_2 = pd.read_csv('../data/raw/manggahan_clinic_dataset.csv')

# %%
data = [data_1, data_2]

merged_data = pd.concat(data, ignore_index=True)

merged_data.to_csv('../data/interim/merged_dataset.csv', index=False)
merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6612 entries, 0 to 6611
# Data columns (total 31 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   CASEID                           5493 non-null   object
#  1   AGE                              6612 non-null   int64
#  2   AGE_GRP                          5493 non-null   float64
#  3   REGION                           6612 non-null   object
#  4   EDUC_LEVEL                       6612 non-null   object
#  5   RELIGION                         6612 non-null   object
#  6   ETHNICITY                        6612 non-null   object
#  7   EDUC                             6612 non-null   object
#  8   HOUSEHOLD_HEAD_SEX               6612 non-null   object
#  9   PARITY                           6612 non-null   int64
#  10  CONTRACEPTIVE_METHOD             6561 non-null   object
#  11  CURRENT_USE_TYPE                 6612 non-null   object
# ...
